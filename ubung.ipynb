# %%
# 2) Indexierung und Slicing
print("t[0]:", t[0])
print("t[-1]:", t[-1])
print("t[1:4]:", t[1:4])
print("t[::2]:", t[::2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 2) Indexierung und Slicing
# ----> 2 print("t[0]:", t[0])
#       3 print("t[-1]:", t[-1])
#       4 print("t[1:4]:", t[1:4])
#
# NameError: name 't' is not defined
